# %% [markdown]
# ### Data and Collection of Data

# %% [markdown]
# For this particular project, we have collected some information on the crime rate from 2014 to 2019 in Toronto

# %% [markdown]
# ### Based on our problem, some factors should be taken into account in order to take the good decision are listed below:
#
# 1. Figure out the safest borough based on Toronto Crime Rate.
# 2. Discover the optimal common venues and select the appropriate neighbourhood within the borough.
#
# ## We will treat the geographical data about Toronto in order to plot the corresponding neighbourhoods which are considered as safe and secure for the opening of a new restaurant.

# %% [markdown]
# The following dataset which is Toronto Crime rate (https://www.kaggle.com/alincijov/toronto-crime-rate-per-neighbourhood) is analysing.
#
# Toronto Neighbourhoods Boundary File includes 2014-2019 Crime Data by Neighbourhood. Counts are available for Assault, Auto Theft, Break and Enter, Robbery, Theft Over and Homicide. Data also includes four year averages and crime rates per 100,000 people by neighbourhood based on 2016 Census Population.
#
# In this project, we extract data from the following data sources:
# 1. Toronto Crime rate (https://www.kaggle.com/alincijov/toronto-crime-rate-per-neighbourhood)
# 2. Restaurants data in every neighborhood will be obtained using Foursquare API
# 3. Google Geocoding API will be used to center the hexagon neighborhood.

# %%
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # conversion an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 


from IPython.display import display_html
import pandas as pd
import numpy as np


import requests # library to handle requests
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans


# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# Libraries imported.

# %% [markdown]
# ### Reading from the Dataset
# We proceed to the Toronto Dataset with the recent crime report from 2008 to 2019.

# %%
# !pip install lxml
import lxml
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
df = pd.read_html(url, header=0)
df = df[0]
df.head()
# Out:
# Requirement already satisfied: lxml in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (4.6.2)
#   Postal Code           Borough              Neighbourhood
# 0         M1A      Not assigned               Not assigned
# 1         M2A      Not assigned               Not assigned
# 2         M3A        North York                  Parkwoods
# 3         M4A        North York           Victoria Village
# 4         M5A  Downtown Toronto  Regent Park, Harbourfront

# %%
# Dropping the rows where Borough is 'Not assigned'
df = df[df.Borough != 'Not assigned']

# Combining the neighbourhoods with same Postalcode
df = df.groupby(['Postal Code','Borough'], sort=False).agg(', '.join)
df.reset_index(inplace=True)

# Replacing the name of the neighbourhoods which are 'Not assigned' with names of Borough
df['Neighbourhood'] = np.where(df['Neighbourhood'] == 'Not assigned',df['Borough'], df['Neighbourhood'])

df.shape
df.head()
# Out:
#   Postal Code           Borough                                Neighbourhood
# 0         M3A        North York                                    Parkwoods
# 1         M4A        North York                             Victoria Village
# 2         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3         M6A        North York             Lawrence Manor, Lawrence Heights
# 4         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government

# %%
#Importing the csv file conatining the latitudes and longitudes for various neighbourhoods in Canada
latitude_longitude = pd.read_csv('https://cocl.us/Geospatial_data')
latitude_longitude.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %% [markdown]
# ### Merging the two tables for getting the Latitudes and Longitudes for various neighbourhoods in Canada

# %%
latitude_longitude.rename(columns={'Postal Code':'Postal Code'},inplace=True)
df = pd.merge(df,latitude_longitude,on='Postal Code')
df
# Out:
#     Postal Code           Borough  \
# 0           M3A        North York
# 1           M4A        North York
# 2           M5A  Downtown Toronto
# 3           M6A        North York
# 4           M7A  Downtown Toronto
# ..          ...               ...
# 98          M8X         Etobicoke
# 99          M4Y  Downtown Toronto
# 100         M7Y      East Toronto
# 101         M8Y         Etobicoke
# 102         M8Z         Etobicoke
#
#                                          Neighbourhood   Latitude  Longitude
# 0                                            Parkwoods  43.753259 -79.329656
# 1                                     Victoria Village  43.725882 -79.315572
# 2                            Regent Park, Harbourfront  43.654260 -79.360636
# 3                     Lawrence Manor, Lawrence Heights  43.718518 -79.464763
# 4          Queen's Park, Ontario Provincial Government  43.662301 -79.389494
# ..                                                 ...        ...        ...
# 98       The Kingsway, Montgomery Road, Old Mill North  43.653654 -79.506944
# 99                                Church and Wellesley  43.665860 -79.383160
# 100  Business reply mail Processing Centre, South C...  43.662744 -79.321558
# 101  Old Mill South, King's Mill Park, Sunnylea, Hu...  43.636258 -79.498509
# 102  Mimico NW, The Queensway West, South of Bloor,...  43.628841 -79.520999
#
# [103 rows x 5 columns]

# %% [markdown]
# ### Merging the three tables for getting the Neighbourhood with the crime Rate

# %%
toronto_Crime_df = pd.read_csv('https://raw.githubusercontent.com/Ellis0312/The-Battle-of-Neighborhoods/main/Neighbourhood_Crime_Rates.csv',index_col='OBJECTID')
toronto_Crime_df.drop(['Assault_2014','Assault_2015','Assault_2016','Assault_2017','Assault_2018','Assault_2019','Assault_AVG','Assault_CHG','AutoTheft_2014','AutoTheft_2015','AutoTheft_2016','AutoTheft_2017','AutoTheft_2018','AutoTheft_2019','AutoTheft_AVG','AutoTheft_CHG','BreakandEnter_2014','BreakandEnter_2015','BreakandEnter_2016','BreakandEnter_2017','BreakandEnter_2018','BreakandEnter_2019','BreakandEnter_AVG','BreakandEnter_CHG','Homicide_2014','Homicide_2015','Homicide_2016','Homicide_2017','Homicide_2018','Homicide_2019','Homicide_CHG','Homicide_AVG','Robbery_2014','Robbery_2015', 'Robbery_2016','Robbery_2017','Robbery_2018','Robbery_2019','Robbery_AVG','Robbery_CHG','TheftOver_2014','TheftOver_2015','TheftOver_2016','TheftOver_2017','TheftOver_2018','TheftOver_2019','TheftOver_AVG','TheftOver_CHG','Shape__Area','Shape__Length'], axis = 1, inplace = True)
toronto_Crime_df
map_toronto_df = pd.merge(df,toronto_Crime_df,on='Neighbourhood')
map_toronto_df
# Out:
#   Postal Code       Borough        Neighbourhood   Latitude  Longitude  \
# 0         M4A    North York     Victoria Village  43.725882 -79.315572
# 1         M6C          York   Humewood-Cedarvale  43.693781 -79.428191
# 2         M4E  East Toronto          The Beaches  43.676357 -79.293031
# 3         M1G   Scarborough               Woburn  43.770992 -79.216917
# 4         M2H    North York    Hillcrest Village  43.803762 -79.363452
# 5         M4H     East York     Thorncliffe Park  43.705369 -79.349372
# 6         M1J   Scarborough  Scarborough Village  43.744734 -79.239476
# 7         M2K    North York      Bayview Village  43.786947 -79.385975
# 8         M9L    North York        Humber Summit  43.756303 -79.565963
# 9         M9N          York               Weston  43.706876 -79.518188
#
#    Hood_ID  Population  Assault_Rate_2019  AutoTheft_Rate_2019  \
# 0       43       17510              753.9                102.8
# 1      106       14365              320.2                111.4
# 2       63       21567              375.6                 92.7
# 3      137       53485              798.4                112.2
# 4       48       16934              407.5                159.4
# 5       55       21108              544.8                 61.6
# 6      139       16724             1046.4                107.6
# 7       52       21396              308.5                172.9
# 8       21       12416              950.4               1087.3
# 9      113       17992             1089.4                272.3
#
#    BreakandEnter_Rate_2019  Homicide_Rate_2019  Robbery_Rate_2019  \
# 0                    342.7                 5.7               80.0
# 1                    181.0                 0.0               69.6
# 2                    264.3                 0.0               74.2
# 3                    187.0                 0.0              125.3
# 4                    212.6                 5.9               94.5
# 5                    127.9                 0.0               61.6
# 6                    239.2                 0.0              167.4
# 7                    172.9                 0.0               65.4
# 8                    459.1                24.2              225.5
# 9                    322.4                11.1              144.5
#
#    TheftOver_Rate_2019
# 0                 28.6
# 1                 27.8
# 2                 41.7
# 3                 15.0
# 4                 35.4
# 5                 23.7
# 6                 12.0
# 7                 60.8
# 8                177.2
# 9                 22.2

# %% [markdown]
# After Data Cleaning of these datasets, we perform the total crime rate in the different types of crime

# %%
#  Calulating the sum of the all crimes committed and Sorting the data

crime_toronto_total = pd.concat([map_toronto_df,pd.DataFrame(map_toronto_df[["Assault_Rate_2019", "AutoTheft_Rate_2019", "BreakandEnter_Rate_2019","Homicide_Rate_2019","Robbery_Rate_2019","TheftOver_Rate_2019"]].sum(axis=1),columns=['Total'])],axis=1)
crime_toronto_total
# Out:
#   Postal Code       Borough        Neighbourhood   Latitude  Longitude  \
# 0         M4A    North York     Victoria Village  43.725882 -79.315572
# 1         M6C          York   Humewood-Cedarvale  43.693781 -79.428191
# 2         M4E  East Toronto          The Beaches  43.676357 -79.293031
# 3         M1G   Scarborough               Woburn  43.770992 -79.216917
# 4         M2H    North York    Hillcrest Village  43.803762 -79.363452
# 5         M4H     East York     Thorncliffe Park  43.705369 -79.349372
# 6         M1J   Scarborough  Scarborough Village  43.744734 -79.239476
# 7         M2K    North York      Bayview Village  43.786947 -79.385975
# 8         M9L    North York        Humber Summit  43.756303 -79.565963
# 9         M9N          York               Weston  43.706876 -79.518188
#
#    Hood_ID  Population  Assault_Rate_2019  AutoTheft_Rate_2019  \
# 0       43       17510              753.9                102.8
# 1      106       14365              320.2                111.4
# 2       63       21567              375.6                 92.7
# 3      137       53485              798.4                112.2
# 4       48       16934              407.5                159.4
# 5       55       21108              544.8                 61.6
# 6      139       16724             1046.4                107.6
# 7       52       21396              308.5                172.9
# 8       21       12416              950.4               1087.3
# 9      113       17992             1089.4                272.3
#
#    BreakandEnter_Rate_2019  Homicide_Rate_2019  Robbery_Rate_2019  \
# 0                    342.7                 5.7               80.0
# 1                    181.0                 0.0               69.6
# 2                    264.3                 0.0               74.2
# 3                    187.0                 0.0              125.3
# 4                    212.6                 5.9               94.5
# 5                    127.9                 0.0               61.6
# 6                    239.2                 0.0              167.4
# 7                    172.9                 0.0               65.4
# 8                    459.1                24.2              225.5
# 9                    322.4                11.1              144.5
#
#    TheftOver_Rate_2019   Total
# 0                 28.6  1313.7
# 1                 27.8   710.0
# 2                 41.7   848.5
# 3                 15.0  1237.9
# 4                 35.4   915.3
# 5                 23.7   819.6
# 6                 12.0  1572.6
# 7                 60.8   780.5
# 8                177.2  2923.7
# 9                 22.2  1861.9

# %% [markdown]
# Sorting the data in order to get the neighbourhood with the top 5 highest crime rate

# %%
# Sorting the data with the highest rate top 5

crime_toronto_total.sort_values(['Total'], ascending = False, axis = 0, inplace = True )

crime_toronto_top5 = crime_toronto_total.iloc[1:6]
crime_toronto_top5
# Out:
#   Postal Code      Borough        Neighbourhood   Latitude  Longitude  \
# 9         M9N         York               Weston  43.706876 -79.518188
# 6         M1J  Scarborough  Scarborough Village  43.744734 -79.239476
# 0         M4A   North York     Victoria Village  43.725882 -79.315572
# 3         M1G  Scarborough               Woburn  43.770992 -79.216917
# 4         M2H   North York    Hillcrest Village  43.803762 -79.363452
#
#    Hood_ID  Population  Assault_Rate_2019  AutoTheft_Rate_2019  \
# 9      113       17992             1089.4                272.3
# 6      139       16724             1046.4                107.6
# 0       43       17510              753.9                102.8
# 3      137       53485              798.4                112.2
# 4       48       16934              407.5                159.4
#
#    BreakandEnter_Rate_2019  Homicide_Rate_2019  Robbery_Rate_2019  \
# 9                    322.4                11.1              144.5
# 6                    239.2                 0.0              167.4
# 0                    342.7                 5.7               80.0
# 3                    187.0                 0.0              125.3
# 4                    212.6                 5.9               94.5
#
#    TheftOver_Rate_2019   Total
# 9                 22.2  1861.9
# 6                 12.0  1572.6
# 0                 28.6  1313.7
# 3                 15.0  1237.9
# 4                 35.4   915.3

# %% [markdown]
# Bar charts Visualization of the top 5 highest crime rate

# %%
import matplotlib.pyplot as plt

crime_neighbourhood = crime_toronto_top5[['Neighbourhood','Total']]

crime_neighbourhood.set_index('Neighbourhood',inplace = True)

ax_x_y = crime_neighbourhood.plot(kind='bar', figsize=(10, 10), rot = 0)

ax_x_y .set_title('Neighbourhoods with the highest rate of crime')
ax_x_y .set_ylabel('Number of Crimes')
ax_x_y .set_xlabel('Neighbourhood')

for t in ax_x_y.patches:
    ax_x_y.annotate(np.round(t.get_height(),decimals=2), 
                (t.get_x()+t.get_width()/2., t.get_height()), 
                ha='center', 
                va='center', 
                xytext=(0, 10), 
                textcoords='offset points',
                fontsize = 12,
               )

plt.show()

# %% [markdown]
# Sorting the data in order to get the neighbourhood with the top 5 lowest crime rate

# %%
crime_toronto_total.sort_values(['Total'], ascending = True, axis = 0, inplace = True )

crime_toronto_top5_low = crime_toronto_total.iloc[1:6]
crime_toronto_top5_low
# Out:
#   Postal Code       Borough      Neighbourhood   Latitude  Longitude  Hood_ID  \
# 7         M2K    North York    Bayview Village  43.786947 -79.385975       52
# 5         M4H     East York   Thorncliffe Park  43.705369 -79.349372       55
# 2         M4E  East Toronto        The Beaches  43.676357 -79.293031       63
# 4         M2H    North York  Hillcrest Village  43.803762 -79.363452       48
# 3         M1G   Scarborough             Woburn  43.770992 -79.216917      137
#
#    Population  Assault_Rate_2019  AutoTheft_Rate_2019  \
# 7       21396              308.5                172.9
# 5       21108              544.8                 61.6
# 2       21567              375.6                 92.7
# 4       16934              407.5                159.4
# 3       53485              798.4                112.2
#
#    BreakandEnter_Rate_2019  Homicide_Rate_2019  Robbery_Rate_2019  \
# 7                    172.9                 0.0               65.4
# 5                    127.9                 0.0               61.6
# 2                    264.3                 0.0               74.2
# 4                    212.6                 5.9               94.5
# 3                    187.0                 0.0              125.3
#
#    TheftOver_Rate_2019   Total
# 7                 60.8   780.5
# 5                 23.7   819.6
# 2                 41.7   848.5
# 4                 35.4   915.3
# 3                 15.0  1237.9

# %%
import matplotlib.pyplot as plt

crime_neighbourhood = crime_toronto_top5_low[['Neighbourhood','Total']]

crime_neighbourhood.set_index('Neighbourhood',inplace = True)

ax_x_y = crime_neighbourhood.plot(kind='bar', figsize=(10, 10), rot = 0)

ax_x_y .set_title('Neighbourhoods with the lowest rate of crime')
ax_x_y .set_ylabel('Number of Crimes')
ax_x_y .set_xlabel('Neighbourhood')

for t in ax_x_y.patches:
    ax_x_y.annotate(np.round(t.get_height(),decimals=2), 
                (t.get_x()+t.get_width()/2., t.get_height()), 
                ha='center', 
                va='center', 
                xytext=(0, 10), 
                textcoords='offset points',
                fontsize = 12,
               )

plt.show()

# %%
#Visualizing all the Neighbourhoods of the above data frame using Folium

map_toronto = folium.Map(location=[43.651070,-79.347015],zoom_start=10)

for lat,lng,borough,neighbourhood in zip(map_toronto_df['Latitude'],map_toronto_df['Longitude'],map_toronto_df['Borough'],map_toronto_df['Neighbourhood']):
    label = '{}, {}'.format(neighbourhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
    [lat,lng],
    radius=5,
    popup=label,
    color='blue',
    fill=True,
    fill_color='#3186cc',
    fill_opacity=0.7,
    parse_html=False).add_to(map_toronto)
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# After analysis of the top 5 lowest crime rate, East York Borough is considered to be the safest place for the establishment of a new restaurant

# %%
East_York_df = crime_toronto_total[crime_toronto_total['Borough'] == 'East York']

East_York_df = East_York_df.sort_values(['Total'], ascending = True, axis = 0)

East_York = East_York_df[['Borough','Assault_Rate_2019', 'AutoTheft_Rate_2019','BreakandEnter_Rate_2019','Homicide_Rate_2019','Robbery_Rate_2019',
                 'TheftOver_Rate_2019']]


East_York.set_index('Borough',inplace = True)

ax_x_y = East_York.plot(kind='bar', figsize=(10, 6), rot=0)

ax_x_y.set_title('Different Kind of Crimes in East York Borough')
ax_x_y.set_ylabel('Number of Crimes')
ax_x_y.set_xlabel('Borough')

for t in ax_x_y.patches:
    ax_x_y.annotate(np.round(t.get_height(),decimals=2), 
                (t.get_x()+t.get_width()/2.,t.get_height()), 
                ha='center', 
                va='center', 
                xytext=(3, 10), 
                textcoords='offset points',
                fontsize = 12
               )
    ax_x_y.legend(loc='upper right')

plt.show()

# %% [markdown]
# We want to have an interactive map of the East York Borough

# %%
df = df[df['Borough'].str.contains('East York',regex=False)]
#Visualizing all the Neighbourhoods of the above data frame using Folium

map_toronto = folium.Map(location=[43.651070,-79.347015],zoom_start=10)

for lat,lng,borough,neighbourhood in zip(df['Latitude'],df['Longitude'],df['Borough'],df['Neighbourhood']):
    label = '{}, {}'.format(neighbourhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
    [lat,lng],
    radius=5,
    popup=label,
    color='blue',
    fill=True,
    fill_color='#3186cc',
    fill_opacity=0.7,
    parse_html=False).add_to(map_toronto)
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Using Foursquare API to get the venue names near the different neighbourhood of East York

# %%
CLIENT_ID = 'XVY0YGK3DX5QGHMN2TGSK2EWA55P3JNPIVC5QVW5SGIGUI2L'
CLIENT_SECRET = 'T53Z3HT4W5DVALRIPBK2DPD4NFOCISMUTMNBLNW13KEJTAIJ'
VERSION = '20191101'
LIMIT = 100


def nearbyVenuesNeigh(names, latitudes, longitudes, radius=1000):
    
    venues_list=[]
    for venue_name, venue_latitude, venue_longtitude in zip(names, latitudes, longitudes):
        print(venue_name)
            
        # use Foursquare API
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, VERSION,venue_latitude, venue_longtitude, radius, LIMIT)
            
        # GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # get information for each nearby venue
        venues_list.append([(
            venue_name, 
            venue_latitude, 
            venue_longtitude, 
            i['venue']['name'], 
            i['venue']['categories'][0]['name']) for i in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighbourhood', 'Neighborhood Latitude', 'Neighborhood Longitude', 'Venue', 'Venue Category']
    
    return(nearby_venues)

# %%
east_York_venues = nearbyVenuesNeigh(names=df['Neighbourhood'],
                                   latitudes=df['Latitude'],
                                   longitudes=df['Longitude']
                                  )
# Out:
# Parkview Hill, Woodbine Gardens
# Woodbine Heights
# Leaside
# Thorncliffe Park
# East Toronto, Broadview North (Old East York)

# %% [markdown]
# Get the near by venue of  East York

# %%
east_York_venues
# Out:
#                                      Neighbourhood  Neighborhood Latitude  \
# 0                  Parkview Hill, Woodbine Gardens              43.706397
# 1                  Parkview Hill, Woodbine Gardens              43.706397
# 2                  Parkview Hill, Woodbine Gardens              43.706397
# 3                  Parkview Hill, Woodbine Gardens              43.706397
# 4                  Parkview Hill, Woodbine Gardens              43.706397
# ..                                             ...                    ...
# 244  East Toronto, Broadview North (Old East York)              43.685347
# 245  East Toronto, Broadview North (Old East York)              43.685347
# 246  East Toronto, Broadview North (Old East York)              43.685347
# 247  East Toronto, Broadview North (Old East York)              43.685347
# 248  East Toronto, Broadview North (Old East York)              43.685347
#
#      Neighborhood Longitude                      Venue         Venue Category
# 0                -79.309937               Jawny Bakers              Gastropub
# 1                -79.309937   Toronto Climbing Academy     Rock Climbing Spot
# 2                -79.309937       East York Gymnastics   Gym / Fitness Center
# 3                -79.309937     Muddy York Brewing Co.                Brewery
# 4                -79.309937  Peek Freans Cookie Outlet                 Bakery
# ..                      ...                        ...                    ...
# 244              -79.338106   Raj Kapuri Paan & Snacks      Indian Restaurant
# 245              -79.338106         Pape Flower Market            Flower Shop
# 246              -79.338106                Phyllo Cafe            Pastry Shop
# 247              -79.338106     Pie in the Sky Studios  Performing Arts Venue
# 248              -79.338106                  Wine Rack              Wine Shop
#
# [249 rows x 5 columns]

# %% [markdown]
# Regrouping the neighbourhood together

# %%
east_York_venues.groupby('Neighbourhood').count().drop(['Neighborhood Latitude','Neighborhood Longitude'], axis = 1)
# Out:
#                                                Venue  Venue Category
# Neighbourhood
# East Toronto, Broadview North (Old East York)     95              95
# Leaside                                           59              59
# Parkview Hill, Woodbine Gardens                   19              19
# Thorncliffe Park                                  49              49
# Woodbine Heights                                  27              27

# %%
nearby_venues_unique = east_York_venues['Venue Category'].value_counts().to_frame(name='Count')
nearby_venues_unique.head(5)
# Out:
#                   Count
# Coffee Shop          20
# Café                  9
# Greek Restaurant      9
# Pizza Place           8
# Sandwich Place        7

# %% [markdown]
# Getting the venue of all restaurants in East York

# %%
east_york_Restaurant= east_York_venues[east_York_venues['Venue Category'].str.contains('Restaurant',regex=False)]
east_york_Restaurant
# Out:
#                                      Neighbourhood  Neighborhood Latitude  \
# 7                  Parkview Hill, Woodbine Gardens              43.706397
# 27                                Woodbine Heights              43.695344
# 41                                Woodbine Heights              43.695344
# 44                                Woodbine Heights              43.695344
# 56                                         Leaside              43.709060
# 60                                         Leaside              43.709060
# 75                                         Leaside              43.709060
# 91                                         Leaside              43.709060
# 96                                         Leaside              43.709060
# 99                                         Leaside              43.709060
# 100                                        Leaside              43.709060
# 108                               Thorncliffe Park              43.705369
# 109                               Thorncliffe Park              43.705369
# 112                               Thorncliffe Park              43.705369
# 123                               Thorncliffe Park              43.705369
# 126                               Thorncliffe Park              43.705369
# 127                               Thorncliffe Park              43.705369
# 130                               Thorncliffe Park              43.705369
# 140                               Thorncliffe Park              43.705369
# 141                               Thorncliffe Park              43.705369
# 142                               Thorncliffe Park              43.705369
# 148                               Thorncliffe Park              43.705369
# 152                               Thorncliffe Park              43.705369
# 153                               Thorncliffe Park              43.705369
# 157  East Toronto, Broadview North (Old East York)              43.685347
# 161  East Toronto, Broadview North (Old East York)              43.685347
# 162  East Toronto, Broadview North (Old East York)              43.685347
# 165  East Toronto, Broadview North (Old East York)              43.685347
# 169  East Toronto, Broadview North (Old East York)              43.685347
# 171  East Toronto, Broadview North (Old East York)              43.685347
# 174  East Toronto, Broadview North (Old East York)              43.685347
# 176  East Toronto, Broadview North (Old East York)              43.685347
# 180  East Toronto, Broadview North (Old East York)              43.685347
# 186  East Toronto, Broadview North (Old East York)              43.685347
# 187  East Toronto, Broadview North (Old East York)              43.685347
# 191  East Toronto, Broadview North (Old East York)              43.685347
# 192  East Toronto, Broadview North (Old East York)              43.685347
# 194  East Toronto, Broadview North (Old East York)              43.685347
# 195  East Toronto, Broadview North (Old East York)              43.685347
# 200  East Toronto, Broadview North (Old East York)              43.685347
# 202  East Toronto, Broadview North (Old East York)              43.685347
# 207  East Toronto, Broadview North (Old East York)              43.685347
# 215  East Toronto, Broadview North (Old East York)              43.685347
# 216  East Toronto, Broadview North (Old East York)              43.685347
# 217  East Toronto, Broadview North (Old East York)              43.685347
# 223  East Toronto, Broadview North (Old East York)              43.685347
# 232  East Toronto, Broadview North (Old East York)              43.685347
# 236  East Toronto, Broadview North (Old East York)              43.685347
# 237  East Toronto, Broadview North (Old East York)              43.685347
# 238  East Toronto, Broadview North (Old East York)              43.685347
# 241  East Toronto, Broadview North (Old East York)              43.685347
# 242  East Toronto, Broadview North (Old East York)              43.685347
# 244  East Toronto, Broadview North (Old East York)              43.685347
#
#      Neighborhood Longitude                                   Venue  \
# 7                -79.309937                                Harvey's
# 27               -79.318389               Little Coxwell Restaurant
# 41               -79.318389                             Thai Fusion
# 44               -79.318389                                 Kouzina
# 56               -79.363452                         The Leaside Pub
# 60               -79.363452             Kintako Japanese Restaurant
# 75               -79.363452                   Mt Everest Restaurant
# 91               -79.363452       Mucho Burrito Fresh Mexican Grill
# 96               -79.363452                         Select Sandwich
# 99               -79.363452                           San Francesco
# 100              -79.363452                               Nigiri-Ya
# 108              -79.349372              Iqbal Kebab & Sweet Centre
# 109              -79.349372                           Bamiyan Kabob
# 112              -79.349372         Pasha Authentic Turkish Cuisine
# 123              -79.349372                        Faley Restaurant
# 126              -79.349372                                     A&W
# 127              -79.349372                            Hakka Garden
# 130              -79.349372                          Afghan Cuisine
# 140              -79.349372                            Swiss Chalet
# 141              -79.349372          Anatolian's Turkish Restaurant
# 142              -79.349372                          Kandahar Kabab
# 148              -79.349372                 Trendee Chinese Cuisine
# 152              -79.349372                           San Francesco
# 153              -79.349372                            Naan & Kabob
# 157              -79.338106                                Mr. Pide
# 161              -79.338106                                The Wren
# 162              -79.338106       Rendez-Vous Restaurant Bar & Cafe
# 165              -79.338106                 Athens Restaurant & Bar
# 169              -79.338106              Danforth Dragon Restaurant
# 171              -79.338106                              City Betty
# 174              -79.338106          Sala Modern Thai Kitchen & Bar
# 176              -79.338106         Al Mandi Restaurant مطعم المندي
# 180              -79.338106                    Ha gow Dim Sum House
# 186              -79.338106  Nakayoshi: Ramen Fine Japanese Cuisine
# 187              -79.338106                                Lalibela
# 191              -79.338106                             Folia Grill
# 192              -79.338106                           Zorba Mezedes
# 194              -79.338106                                Tzatziki
# 195              -79.338106                                     A&W
# 200              -79.338106                      Akropolis Pastries
# 202              -79.338106             Wazema Ethiopian Restaurant
# 207              -79.338106                                     A&W
# 215              -79.338106           Number One Chinese Restaurant
# 216              -79.338106                       Makkah Restaurant
# 217              -79.338106                                     KFC
# 223              -79.338106       El Sol Mexican Gallery Restaurant
# 232              -79.338106                     Kings Bar and Grill
# 236              -79.338106                            Pape Village
# 237              -79.338106                       Pita King & Grill
# 238              -79.338106                           Pho Challenge
# 241              -79.338106                        Paul's Spaghetti
# 242              -79.338106                    East York Restaurant
# 244              -79.338106                Raj Kapuri Paan & Snacks
#
#                 Venue Category
# 7         Fast Food Restaurant
# 27             Thai Restaurant
# 41             Thai Restaurant
# 44            Greek Restaurant
# 56                  Restaurant
# 60            Sushi Restaurant
# 75           Indian Restaurant
# 91          Mexican Restaurant
# 96                  Restaurant
# 99          Italian Restaurant
# 100        Japanese Restaurant
# 108          Indian Restaurant
# 109          Afghan Restaurant
# 112         Turkish Restaurant
# 123          Indian Restaurant
# 126       Fast Food Restaurant
# 127          Indian Restaurant
# 130          Afghan Restaurant
# 140                 Restaurant
# 141         Turkish Restaurant
# 142  Middle Eastern Restaurant
# 148           Asian Restaurant
# 152         Italian Restaurant
# 153  Middle Eastern Restaurant
# 157         Turkish Restaurant
# 161        American Restaurant
# 162       Ethiopian Restaurant
# 165           Greek Restaurant
# 169           Asian Restaurant
# 171        American Restaurant
# 174            Thai Restaurant
# 176  Middle Eastern Restaurant
# 180         Dim Sum Restaurant
# 186           Ramen Restaurant
# 187       Ethiopian Restaurant
# 191           Greek Restaurant
# 192           Greek Restaurant
# 194           Greek Restaurant
# 195       Fast Food Restaurant
# 200           Greek Restaurant
# 202       Ethiopian Restaurant
# 207       Fast Food Restaurant
# 215         Chinese Restaurant
# 216                 Restaurant
# 217       Fast Food Restaurant
# 223         Mexican Restaurant
# 232           Greek Restaurant
# 236           Greek Restaurant
# 237  Middle Eastern Restaurant
# 238      Vietnamese Restaurant
# 241         Italian Restaurant
# 242           Greek Restaurant
# 244          Indian Restaurant

# %% [markdown]
# Analyze Each Neighbourhood

# %%
# one hot encoding
east_york_onehot = pd.get_dummies(east_york_Restaurant[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
east_york_onehot['Neighbourhood'] = east_york_Restaurant['Neighbourhood'] 

# move neighborhood column to the first column
fixed_columns = [east_york_onehot.columns[-1]] + list(east_york_onehot.columns[:-1])
east_york_onehot =east_york_onehot[fixed_columns]

east_york_onehot.head()
# Out:
#                       Neighbourhood  Afghan Restaurant  American Restaurant  \
# 7   Parkview Hill, Woodbine Gardens                  0                    0
# 27                 Woodbine Heights                  0                    0
# 41                 Woodbine Heights                  0                    0
# 44                 Woodbine Heights                  0                    0
# 56                          Leaside                  0                    0
#
#     Asian Restaurant  Chinese Restaurant  Dim Sum Restaurant  \
# 7                  0                   0                   0
# 27                 0                   0                   0
# 41                 0                   0                   0
# 44                 0                   0                   0
# 56                 0                   0                   0
#
#     Ethiopian Restaurant  Fast Food Restaurant  Greek Restaurant  \
# 7                      0                     1                 0
# 27                     0                     0                 0
# 41                     0                     0                 0
# 44                     0                     0                 1
# 56                     0                     0                 0
#
#     Indian Restaurant  Italian Restaurant  Japanese Restaurant  \
# 7                   0                   0                    0
# 27                  0                   0                    0
# 41                  0                   0                    0
# 44                  0                   0                    0
# 56                  0                   0                    0
#
#     Mexican Restaurant  Middle Eastern Restaurant  Ramen Restaurant  \
# 7                    0                          0                 0
# 27                   0                          0                 0
# 41                   0                          0                 0
# 44                   0                          0                 0
# 56                   0                          0                 0
#
#     Restaurant  Sushi Restaurant  Thai Restaurant  Turkish Restaurant  \
# 7            0                 0                0                   0
# 27           0                 0                1                   0
# 41           0                 0                1                   0
# 44           0                 0                0                   0
# 56           1                 0                0                   0
#
#     Vietnamese Restaurant
# 7                       0
# 27                      0
# 41                      0
# 44                      0
# 56                      0

# %%
east_york_grouped = east_york_onehot.groupby('Neighbourhood').mean().reset_index()
east_york_grouped
# Out:
#                                    Neighbourhood  Afghan Restaurant  \
# 0  East Toronto, Broadview North (Old East York)           0.000000
# 1                                        Leaside           0.000000
# 2                Parkview Hill, Woodbine Gardens           0.000000
# 3                               Thorncliffe Park           0.153846
# 4                               Woodbine Heights           0.000000
#
#    American Restaurant  Asian Restaurant  Chinese Restaurant  \
# 0             0.068966          0.034483            0.034483
# 1             0.000000          0.000000            0.000000
# 2             0.000000          0.000000            0.000000
# 3             0.000000          0.076923            0.000000
# 4             0.000000          0.000000            0.000000
#
#    Dim Sum Restaurant  Ethiopian Restaurant  Fast Food Restaurant  \
# 0            0.034483              0.103448              0.103448
# 1            0.000000              0.000000              0.000000
# 2            0.000000              0.000000              1.000000
# 3            0.000000              0.000000              0.076923
# 4            0.000000              0.000000              0.000000
#
#    Greek Restaurant  Indian Restaurant  Italian Restaurant  \
# 0          0.275862           0.034483            0.034483
# 1          0.000000           0.142857            0.142857
# 2          0.000000           0.000000            0.000000
# 3          0.000000           0.230769            0.076923
# 4          0.333333           0.000000            0.000000
#
#    Japanese Restaurant  Mexican Restaurant  Middle Eastern Restaurant  \
# 0             0.000000            0.034483                   0.068966
# 1             0.142857            0.142857                   0.000000
# 2             0.000000            0.000000                   0.000000
# 3             0.000000            0.000000                   0.153846
# 4             0.000000            0.000000                   0.000000
#
#    Ramen Restaurant  Restaurant  Sushi Restaurant  Thai Restaurant  \
# 0          0.034483    0.034483          0.000000         0.034483
# 1          0.000000    0.285714          0.142857         0.000000
# 2          0.000000    0.000000          0.000000         0.000000
# 3          0.000000    0.076923          0.000000         0.000000
# 4          0.000000    0.000000          0.000000         0.666667
#
#    Turkish Restaurant  Vietnamese Restaurant
# 0            0.034483               0.034483
# 1            0.000000               0.000000
# 2            0.000000               0.000000
# 3            0.153846               0.000000
# 4            0.000000               0.000000

# %% [markdown]
# Get each neighborhood along with the top 5 most common venues

# %%
num_top_venues = 5

for hood in east_york_grouped['Neighbourhood']:
    print("----"+hood+"----")
    temp = east_york_grouped[east_york_grouped['Neighbourhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----East Toronto, Broadview North (Old East York)----
#                        venue  freq
# 0           Greek Restaurant  0.28
# 1       Ethiopian Restaurant  0.10
# 2       Fast Food Restaurant  0.10
# 3        American Restaurant  0.07
# 4  Middle Eastern Restaurant  0.07
#
#
# ----Leaside----
#                  venue  freq
# 0           Restaurant  0.29
# 1   Italian Restaurant  0.14
# 2  Japanese Restaurant  0.14
# 3     Sushi Restaurant  0.14
# 4    Indian Restaurant  0.14
#
#
# ----Parkview Hill, Woodbine Gardens----
#                   venue  freq
# 0  Fast Food Restaurant   1.0
# 1     Afghan Restaurant   0.0
# 2   Japanese Restaurant   0.0
# 3    Turkish Restaurant   0.0
# 4       Thai Restaurant   0.0
#
#
# ----Thorncliffe Park----
#                        venue  freq
# 0          Indian Restaurant  0.23
# 1          Afghan Restaurant  0.15
# 2         Turkish Restaurant  0.15
# 3  Middle Eastern Restaurant  0.15
# 4       Fast Food Restaurant  0.08
#
#
# ----Woodbine Heights----
#                  venue  freq
# 0      Thai Restaurant  0.67
# 1     Greek Restaurant  0.33
# 2    Afghan Restaurant  0.00
# 3  Japanese Restaurant  0.00
# 4   Turkish Restaurant  0.00

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighbourhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighbourhood'] = east_york_grouped['Neighbourhood']

for ind in np.arange(east_york_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(east_york_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#                                    Neighbourhood 1st Most Common Venue  \
# 0  East Toronto, Broadview North (Old East York)      Greek Restaurant
# 1                                        Leaside            Restaurant
# 2                Parkview Hill, Woodbine Gardens  Fast Food Restaurant
# 3                               Thorncliffe Park     Indian Restaurant
# 4                               Woodbine Heights       Thai Restaurant
#
#    2nd Most Common Venue      3rd Most Common Venue 4th Most Common Venue  \
# 0   Ethiopian Restaurant       Fast Food Restaurant   American Restaurant
# 1     Italian Restaurant           Sushi Restaurant    Mexican Restaurant
# 2  Vietnamese Restaurant          Indian Restaurant   American Restaurant
# 3      Afghan Restaurant  Middle Eastern Restaurant    Turkish Restaurant
# 4       Greek Restaurant      Vietnamese Restaurant     Indian Restaurant
#
#        5th Most Common Venue  6th Most Common Venue 7th Most Common Venue  \
# 0  Middle Eastern Restaurant  Vietnamese Restaurant     Indian Restaurant
# 1        Japanese Restaurant      Indian Restaurant  Fast Food Restaurant
# 2           Asian Restaurant     Chinese Restaurant    Dim Sum Restaurant
# 3           Asian Restaurant   Fast Food Restaurant    Italian Restaurant
# 4        American Restaurant       Asian Restaurant    Chinese Restaurant
#
#   8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0      Asian Restaurant    Chinese Restaurant     Dim Sum Restaurant
# 1   American Restaurant      Asian Restaurant     Chinese Restaurant
# 2  Ethiopian Restaurant      Greek Restaurant     Italian Restaurant
# 3            Restaurant    Mexican Restaurant    Japanese Restaurant
# 4    Dim Sum Restaurant  Ethiopian Restaurant   Fast Food Restaurant

# %% [markdown]
# K Means Clustering of the each neighbourhood

# %%
#k=5
#East_York_clustering = east_york_Restaurant.drop(['Venue','Venue Category','Neighbourhood'],1)
#kmeans = KMeans(n_clusters = k,random_state=0).fit(East_York_clustering)
#kmeans.labels_
#east_york_Restaurant.insert(0, 'Cluster Labels', kmeans.labels_)
#east_york_Restaurant

# set number of clusters
kclusters = 5

east_york_grouped_clustering = east_york_grouped.drop('Neighbourhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(east_york_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([3, 4, 2, 1, 0], dtype=int32)

# %%
# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

east_york_merged = df

# match/merge SE London data with latitude/longitude for each neighborhood
east_york_merged_latlong = east_york_merged.join(neighborhoods_venues_sorted.set_index('Neighbourhood'), on = 'Neighbourhood')
east_york_merged_latlong.head()
# Out:
#    Postal Code    Borough                                  Neighbourhood  \
# 8          M4B  East York                Parkview Hill, Woodbine Gardens
# 14         M4C  East York                               Woodbine Heights
# 23         M4G  East York                                        Leaside
# 29         M4H  East York                               Thorncliffe Park
# 35         M4J  East York  East Toronto, Broadview North (Old East York)
#
#      Latitude  Longitude  Cluster Labels 1st Most Common Venue  \
# 8   43.706397 -79.309937               2  Fast Food Restaurant
# 14  43.695344 -79.318389               0       Thai Restaurant
# 23  43.709060 -79.363452               4            Restaurant
# 29  43.705369 -79.349372               1     Indian Restaurant
# 35  43.685347 -79.338106               3      Greek Restaurant
#
#     2nd Most Common Venue      3rd Most Common Venue 4th Most Common Venue  \
# 8   Vietnamese Restaurant          Indian Restaurant   American Restaurant
# 14       Greek Restaurant      Vietnamese Restaurant     Indian Restaurant
# 23     Italian Restaurant           Sushi Restaurant    Mexican Restaurant
# 29      Afghan Restaurant  Middle Eastern Restaurant    Turkish Restaurant
# 35   Ethiopian Restaurant       Fast Food Restaurant   American Restaurant
#
#         5th Most Common Venue  6th Most Common Venue 7th Most Common Venue  \
# 8            Asian Restaurant     Chinese Restaurant    Dim Sum Restaurant
# 14        American Restaurant       Asian Restaurant    Chinese Restaurant
# 23        Japanese Restaurant      Indian Restaurant  Fast Food Restaurant
# 29           Asian Restaurant   Fast Food Restaurant    Italian Restaurant
# 35  Middle Eastern Restaurant  Vietnamese Restaurant     Indian Restaurant
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 8   Ethiopian Restaurant      Greek Restaurant     Italian Restaurant
# 14    Dim Sum Restaurant  Ethiopian Restaurant   Fast Food Restaurant
# 23   American Restaurant      Asian Restaurant     Chinese Restaurant
# 29            Restaurant    Mexican Restaurant    Japanese Restaurant
# 35      Asian Restaurant    Chinese Restaurant     Dim Sum Restaurant

# %%
# create map

map_clusters = folium.Map(location=[43.651070,-79.347015],zoom_start=10)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(east_york_merged_latlong['Latitude'], east_york_merged_latlong['Longitude'],east_york_merged_latlong['Neighbourhood'], east_york_merged_latlong['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Analysis of the 5 clusters

# %%
east_york_merged_latlong.loc[east_york_merged_latlong['Cluster Labels'] == 0, east_york_merged_latlong.columns[[1] + list(range(5, east_york_merged_latlong.shape[1]))]]
# Out:
#       Borough  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 14  East York               0       Thai Restaurant      Greek Restaurant
#
#     3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 14  Vietnamese Restaurant     Indian Restaurant   American Restaurant
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 14      Asian Restaurant    Chinese Restaurant    Dim Sum Restaurant
#
#    9th Most Common Venue 10th Most Common Venue
# 14  Ethiopian Restaurant   Fast Food Restaurant

# %% [markdown]
# Cluster 2

# %%
east_york_merged_latlong.loc[east_york_merged_latlong['Cluster Labels'] == 1, east_york_merged_latlong.columns[[1] + list(range(5, east_york_merged_latlong.shape[1]))]]
# Out:
#       Borough  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 29  East York               1     Indian Restaurant     Afghan Restaurant
#
#         3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 29  Middle Eastern Restaurant    Turkish Restaurant      Asian Restaurant
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 29  Fast Food Restaurant    Italian Restaurant            Restaurant
#
#    9th Most Common Venue 10th Most Common Venue
# 29    Mexican Restaurant    Japanese Restaurant

# %% [markdown]
# Cluster 3

# %%
east_york_merged_latlong.loc[east_york_merged_latlong['Cluster Labels'] == 2, east_york_merged_latlong.columns[[1] + list(range(5, east_york_merged_latlong.shape[1]))]]
# Out:
#      Borough  Cluster Labels 1st Most Common Venue  2nd Most Common Venue  \
# 8  East York               2  Fast Food Restaurant  Vietnamese Restaurant
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 8     Indian Restaurant   American Restaurant      Asian Restaurant
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 8    Chinese Restaurant    Dim Sum Restaurant  Ethiopian Restaurant
#
#   9th Most Common Venue 10th Most Common Venue
# 8      Greek Restaurant     Italian Restaurant

# %% [markdown]
# Cluster 4

# %%
east_york_merged_latlong.loc[east_york_merged_latlong['Cluster Labels'] == 3, east_york_merged_latlong.columns[[1] + list(range(5, east_york_merged_latlong.shape[1]))]]
# Out:
#       Borough  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 35  East York               3      Greek Restaurant  Ethiopian Restaurant
#
#    3rd Most Common Venue 4th Most Common Venue      5th Most Common Venue  \
# 35  Fast Food Restaurant   American Restaurant  Middle Eastern Restaurant
#
#     6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 35  Vietnamese Restaurant     Indian Restaurant      Asian Restaurant
#
#    9th Most Common Venue 10th Most Common Venue
# 35    Chinese Restaurant     Dim Sum Restaurant

# %% [markdown]
# Cluster 5

# %%
east_york_merged_latlong.loc[east_york_merged_latlong['Cluster Labels'] == 4, east_york_merged_latlong.columns[[1] + list(range(5, east_york_merged_latlong.shape[1]))]]
# Out:
#       Borough  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 23  East York               4            Restaurant    Italian Restaurant
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 23      Sushi Restaurant    Mexican Restaurant   Japanese Restaurant
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 23     Indian Restaurant  Fast Food Restaurant   American Restaurant
#
#    9th Most Common Venue 10th Most Common Venue
# 23      Asian Restaurant     Chinese Restaurant
